# %% [markdown]
# # Ettoday 網路爬蟲實作練習
#
#
# * 能夠利用 Request + BeatifulSour 撰寫爬蟲，並存放到合適的資料結構

# %% [markdown]
# ## 作業目標
#
# 根據範例 ，完成以下問題：
#
# * ① 取出今天所有的發文
# * ② 如果想要依照類別分類，怎麼儲存會比較好？
# * ③ 哪一個類別的文章最多

# %% [markdown]
# ### ① 取出今天所有的發文

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
url='https://www.ettoday.net/news/news-list.htm'
r=requests.get(url)
soup=BeautifulSoup(r.text,'html5lib')
x=soup.find('div',class_='part_list_2').find_all('h3')
em={}
for i in x:
    cate=i.find('em').text
    em[cate] = em.get(cate,0) + 1
    print('%s %s %s' % (i.find('span').text,i.find('em').text,i.find('a').text))
# Out:
# 2019/12/15 15:56 大陸 四川宜賓媒礦滲水事故4死14失蹤　被挖出頻頻出事、被行政處罰
# 2019/12/15 15:54 社會 玉井縱火嫌家暴「痛打醫師爸」10多次！家人申請保護令　教友曝：已經放棄他
# 2019/12/15 15:51 政治 政黨激辯兩岸政策　張顯耀批民進黨：抗中保台解決不了台灣問題
# 2019/12/15 15:50 體育 冬盟／味全龍擊敗中職奪季軍　葉總：老實說沒想到
# 2019/12/15 15:48 生活 卡韓？愛情摩天輪計畫停滯⋯港務公司打臉「無業者洽談開發」
# 2019/12/15 15:48 體育 冬盟／葉總調整有效！徐若熙開心奪首勝　助味全拿季軍
# 2019/12/15 15:47 地方 前進到「大贏」 從下營前進大營台南競總車隊開跑！
# 2019/12/15 15:45 體育 中職／學弟王正棠打破自己的紀錄　高孝儀暖心舉動
# 2019/12/15 15:43 國際 老媽贏3億樂透「買亂倫書送兒子當禮物」　親妹洗澡慘遭破門奪童貞！
# 2019/12/15 15:40 寵物動物 陌生人來家裡怕怕！　貓頭鷹躲腳邊「拉衣角害羞」萌暈萬人
# 2019/12/15 15:39 體育 蔣介文為女兒復出衝刺台北馬　與朱穎盈稱霸國內男女組
# 2019/12/15 15:35 體育 羽球年終賽／桃田賢斗逆轉金廷奪冠　單季11冠第一人超越李宗偉
# 2019/12/15 15:33 生活 搭機捷看五月天！　限量演場會版「夜光紋身貼紙」免費送
# 2019/12/15 15:31 體育 平鎮王牌李晨薰赴美動韌帶移植手術　羅健銘：相信他能復出
# 2019/12/15 15:30 體育 雷納德輪休　拉文準絕殺三分打終結快艇4連勝
# 2019/12/15 15:30 影劇 《天空之城》趙炳圭只稱讚大4歲朴恩玭！　南宮珉吃醋「連咳好幾聲」暗示…全場笑翻
# 2019/12/15 15:25 生活 遠航爭復飛⋯交通部要「從嚴審查」　學者：三大層面說清楚才能過關
# 2019/12/15 15:24 政治 網傳選舉奧步！讓韓粉票成廢票　民進黨：天方夜譚！造謠再添一筆
# 2019/12/15 15:20 寵物動物 忘記熄火！愛犬將車開進池塘　主人一臉懵懂傻在岸邊
# ...

# %% [markdown]
# ### ② 如果想要依照類別分類，怎麼儲存會比較好？

# %%
print('用一個字典把類別當成key，數量是value存起來')
# Out:
# 用一個字典把類別當成key，數量是value存起來

# %% [markdown]
# ### ③ 哪一個類別的文章最多

# %%
print("%s最多共有%d則" % (max(em,key=em.get),em[max(em,key=em.get)]))
# Out:
# 體育最多共有22則

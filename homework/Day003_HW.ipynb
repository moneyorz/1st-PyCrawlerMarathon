# %% [markdown]
# # Python 下載XML檔案與解析
#
#
# * 了解 xml 檔案格式與內容
# * 能夠利用套件存取 xml 格式的檔案

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「File I/O」與「xmltodict」讀出來的內容有什麼差異
#
# * 根據範例檔案的結果：
#     1. 請問高雄市有多少地區有溫度資料？
#     2. 請取出每一個地區所記錄的第一個時間點跟溫度
#     3. 請取出第一個地區所記錄的每一個時間點跟溫度

# %% [markdown]
# ### 比較一下範例檔案中的「File I/O」與「xmltodict」讀出來的內容有什麼差異

# %%
with open("./data/64_72hr_CH.xml",encoding='utf-8') as file:
    print(file.read())

import xmltodict
with open('./data/64_72hr_CH.xml',encoding='utf-8') as fd:
    doc=dict(xmltodict.parse(fd.read()))
    #print(doc)

# %% [markdown]
# ### 根據範例檔案的結果：
#
# 1. 請問高雄市有多少地區有溫度資料？
# 2. 請取出每一個地區所記錄的第一個時間點跟溫度
# 3. 請取出第一個地區所記錄的每一個時間點跟溫度

# %%
# 1. 請問高雄市有多少地區有溫度資料？
with open('./data/64_72hr_CH.xml',encoding='utf-8') as fd:
     doc = dict(xmltodict.parse(fd.read())) 
location=doc["cwbopendata"]["dataset"]["locations"]["location"]
for x in location:
   print(x["locationName"])
# Out:
# 鹽埕區
# 鼓山區
# 左營區
# 楠梓區
# 三民區
# 新興區
# 前金區
# 苓雅區
# 前鎮區
# 旗津區
# 小港區
# 鳳山區
# 林園區
# 大寮區
# 大樹區
# 大社區
# 仁武區
# 鳥松區
# 岡山區
# 橋頭區
# 燕巢區
# 田寮區
# 阿蓮區
# 路竹區
# 湖內區
# 茄萣區
# 永安區
# 彌陀區
# 梓官區
# 旗山區
# 美濃區
# 六龜區
# 甲仙區
# 杉林區
# 內門區
# 茂林區
# 桃源區
# 那瑪夏區

# %%
# 2. 請取出每一個地區所記錄的第一個時間點跟溫度
for x in location:
    print("==========================")
    print("地區:"+ x["locationName"])
    et=x["weatherElement"][0]["time"] #每天溫度
    print("時間:" + str(et[0]["dataTime"])+"\t"+"溫度"+ str(et[0]["elementValue"]["value"]))
# Out:
# ==========================
# 地區:鹽埕區
# 時間:2019-06-28T12:00:00+08:00	溫度33
# ==========================
# 地區:鼓山區
# 時間:2019-06-28T12:00:00+08:00	溫度33
# ==========================
# 地區:左營區
# 時間:2019-06-28T12:00:00+08:00	溫度33
# ==========================
# 地區:楠梓區
# 時間:2019-06-28T12:00:00+08:00	溫度34
# ==========================
# 地區:三民區
# 時間:2019-06-28T12:00:00+08:00	溫度32
# ==========================
# 地區:新興區
# 時間:2019-06-28T12:00:00+08:00	溫度33
# ==========================
# 地區:前金區
# 時間:2019-06-28T12:00:00+08:00	溫度33
# ==========================
# 地區:苓雅區
# 時間:2019-06-28T12:00:00+08:00	溫度33
# ==========================
# 地區:前鎮區
# 時間:2019-06-28T12:00:00+08:00	溫度33
# ==========================
# 地區:旗津區
# 時間:2019-06-28T12:00:00+08:00	溫度32
# ==========================
# 地區:小港區
# 時間:2019-06-28T12:00:00+08:00	溫度33
# ==========================
# 地區:鳳山區
# 時間:2019-06-28T12:00:00+08:00	溫度34
# ==========================
# 地區:林園區
# 時間:2019-06-28T12:00:00+08:00	溫度33
# ==========================
# 地區:大寮區
# 時間:2019-06-28T12:00:00+08:00	溫度34
# ==========================
# 地區:大樹區
# 時間:2019-06-28T12:00:00+08:00	溫度34
# ==========================
# 地區:大社區
# 時間:2019-06-28T12:00:00+08:00	溫度34
# ==========================
# 地區:仁武區
# 時間:2019-06-28T12:00:00+08:00	溫度33
# ==========================
# 地區:鳥松區
# 時間:2019-06-28T12:00:00+08:00	溫度34
# ==========================
# 地區:岡山區
# 時間:2019-06-28T12:00:00+08:00	溫度34
# ==========================
# 地區:橋頭區
# 時間:2019-06-28T12:00:00+08:00	溫度35
# ==========================
# 地區:燕巢區
# 時間:2019-06-28T12:00:00+08:00	溫度34
# ==========================
# 地區:田寮區
# 時間:2019-06-28T12:00:00+08:00	溫度34
# ==========================
# 地區:阿蓮區
# 時間:2019-06-28T12:00:00+08:00	溫度34
# ==========================
# 地區:路竹區
# 時間:2019-06-28T12:00:00+08:00	溫度33
# ==========================
# 地區:湖內區
# 時間:2019-06-28T12:00:00+08:00	溫度33
# ==========================
# 地區:茄萣區
# 時間:2019-06-28T12:00:00+08:00	溫度33
# ==========================
# 地區:永安區
# 時間:2019-06-28T12:00:00+08:00	溫度32
# ==========================
# 地區:彌陀區
# 時間:2019-06-28T12:00:00+08:00	溫度32
# ==========================
# 地區:梓官區
# 時間:2019-06-28T12:00:00+08:00	溫度32
# ==========================
# 地區:旗山區
# 時間:2019-06-28T12:00:00+08:00	溫度34
# ==========================
# 地區:美濃區
# 時間:2019-06-28T12:00:00+08:00	溫度34
# ==========================
# 地區:六龜區
# 時間:2019-06-28T12:00:00+08:00	溫度34
# ==========================
# 地區:甲仙區
# 時間:2019-06-28T12:00:00+08:00	溫度33
# ==========================
# 地區:杉林區
# 時間:2019-06-28T12:00:00+08:00	溫度36
# ==========================
# 地區:內門區
# 時間:2019-06-28T12:00:00+08:00	溫度34
# ==========================
# 地區:茂林區
# 時間:2019-06-28T12:00:00+08:00	溫度34
# ==========================
# 地區:桃源區
# 時間:2019-06-28T12:00:00+08:00	溫度31
# ==========================
# 地區:那瑪夏區
# 時間:2019-06-28T12:00:00+08:00	溫度29

# %%
# 3. 請取出第一個地區所記錄的每一個時間點跟溫度

for x in location[:1]:
    print("==========================")
    print("地區:"+ x["locationName"])
    et=x["weatherElement"][0]["time"] #每天溫度
    for y in et:
        print("時間:" + str(y["dataTime"])+"\t"+"溫度"+ str(y["elementValue"]["value"]))
# Out:
# ==========================
# 地區:鹽埕區
# 時間:2019-06-28T12:00:00+08:00	溫度33
# 時間:2019-06-28T15:00:00+08:00	溫度33
# 時間:2019-06-28T18:00:00+08:00	溫度32
# 時間:2019-06-28T21:00:00+08:00	溫度30
# 時間:2019-06-29T00:00:00+08:00	溫度30
# 時間:2019-06-29T03:00:00+08:00	溫度29
# 時間:2019-06-29T06:00:00+08:00	溫度28
# 時間:2019-06-29T09:00:00+08:00	溫度31
# 時間:2019-06-29T12:00:00+08:00	溫度32
# 時間:2019-06-29T15:00:00+08:00	溫度32
# 時間:2019-06-29T18:00:00+08:00	溫度31
# 時間:2019-06-29T21:00:00+08:00	溫度30
# 時間:2019-06-30T00:00:00+08:00	溫度29
# 時間:2019-06-30T03:00:00+08:00	溫度28
# 時間:2019-06-30T06:00:00+08:00	溫度28
# 時間:2019-06-30T09:00:00+08:00	溫度31
# 時間:2019-06-30T12:00:00+08:00	溫度32
# 時間:2019-06-30T15:00:00+08:00	溫度32
# 時間:2019-06-30T18:00:00+08:00	溫度31
# 時間:2019-06-30T21:00:00+08:00	溫度30
# 時間:2019-07-01T00:00:00+08:00	溫度29
# 時間:2019-07-01T03:00:00+08:00	溫度29
# 時間:2019-07-01T06:00:00+08:00	溫度28
# 時間:2019-07-01T09:00:00+08:00	溫度31
